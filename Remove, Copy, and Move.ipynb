# %% [markdown]
# # Initial Notebook

# %%
cd remove_copy_move

# %%
pwd
# Out:
# /mnt/d/pinkt/Documents/GitHub-ProgressivePull/Bash-Deep-Dives/remove_copy_move

# %% [markdown]
# # 🗑 Removing files and folders (rm)
# **rm** deletes files, and **rm -r** deletes directories recursively.

# %%
touch file.txt

# %%
ls
# Out:
# file.txt

# %%
# Remove a single file
rm file.txt

# %%
ls

# %%
echo -e "#file1/nThe First File" > file1.txt

# %%
cat file1.txt
# Out:
# #file1/nThe First File
