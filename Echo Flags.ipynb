# %% [markdown]
# ## Common escape sequences when using -e
# * ```\n``` — newline
#
# * ```\t``` — tab
#
# * ```\r``` — carriage return (overwrites the line)
#
# * ```\\``` — backslash
#
# * ```\"``` — double quote

# %% [markdown]
# # Initial State

# %%
cd /mnt/d/pinkt/Documents/GitHub-ProgressivePull/Bash-Deep-Dives/echo_flag

# %%
pwd
# Out:
# /mnt/d/pinkt/Documents/GitHub-ProgressivePull/Bash-Deep-Dives/echo_flag

# %%
ls

# %% [markdown]
# # New Line Flag

# %%
echo -e "First line\nSecond line"
# Out:
# First line
# Second line

# %% [markdown]
# # When to use printf instead
# **echo** is simple but inconsistent across shells. **printf** gives exact control:

# %%
printf "Hello\nWorld\n"
# Out:
# Hello
# World

# %% [markdown]
# # Create **file1.md** file

# %%
echo -e "# file1\nThe First File" > file1.md

# %%
cat file1.md
# Out:
# # file1
# The First File

# %%
ls
# Out:
# file1.md
