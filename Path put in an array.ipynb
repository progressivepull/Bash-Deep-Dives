# %%
# Get absolute path of this directory (optional, kept for context)
ROOT_DIR="$(pwd)"
# Out:
# /mnt/d/pinkt/Documents/GitHub-ProgressivePull/Bash-Deep-Dives

# %%
echo "$ROOT_DIR"
# Out:
# /mnt/d/pinkt/Documents/GitHub-ProgressivePull/Bash-Deep-Dives

# %%
cd "$ROOT_DIR/mass_convert"

# %%
pwd
# Out:
# /mnt/d/pinkt/Documents/GitHub-ProgressivePull/Bash-Deep-Dives/mass_convert

# %%
cd ..

# %%
pwd
# Out:
# /mnt/d/pinkt/Documents/GitHub-ProgressivePull/Bash-Deep-Dives

# %%
CURRENT_DIR="$(basename "$(pwd)")"
echo "$CURRENT_DIR"
# Out:
# Bash-Deep-Dives
